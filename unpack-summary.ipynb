# %%
# imports
# %reload_ext autoreload
# %autoreload 2

from basic_utils import *
import matplotlib.pyplot as plt

dates = read_dates('summary')
# Out:
# Loading config.json

# %%
symbol_col = 'symbol'
symbol = 'BND'
path = get_path('summary', dates[-3])
fileList = list_files('summary', dates[0])

# %%
path + json_ext.format(symbol)
# Out:
# 'summary/2019-02-06/BND.json'

# %%
summary = json_load(path + json_ext.format(symbol))[0]

# %% [markdown]
# #### processing functions

# %%
summary.keys()
# summary['assetProfile']['companyOfficers']
# Out:
# dict_keys(['assetProfile', 'fundProfile', 'defaultKeyStatistics', 'topHoldings', 'fundPerformance'])

# %%
# lambdas
show_structure = lambda dict_struct: {k: type(v) for k, v in dict_struct.items()}
remove_empty_keys = lambda dict_struct: {k: v for k, v in dict_struct.items() if dict_struct[k]}
get_column_order = lambda route: list(remove_empty_keys(route))
get_symbol_index = lambda route, indexKey: [indexKey for x in range(len(route))]

def create_df(route, indexKey):
    order = get_column_order(route[-1])
    df = pd.DataFrame(route)[order]
    df = set_symbol(df, indexKey)
    return df
def create_normalized_df(route, indexKey):
    order = get_column_order(route[-1])
    df = clean_up_fmt(json_normalize(route))[order]
    df = set_symbol(df, indexKey)
    return df
def clean_single_row_df(route):
    order = get_column_order(route)
    df = clean_up_fmt(json_normalize(route))[order]
    return df
def single_row_df(route, indexKey):
    df = clean_single_row_df(route)
    df = set_symbol(df, indexKey)
    return df

def set_storeDate(df, date):
    df['storeDate'] = datetime.strptime(str(date), '%Y-%m-%d').timestamp()
    return df
def set_symbol(df, symbol):
    df[symbol_col] = symbol
    return df

fin_stmt_mappings = {
    "CF":{"A":"cashflowStatementHistory",
        "Q":"cashflowStatementHistoryQuarterly",
        "B":"cashflowStatements"},
    "BS":{"A":"balanceSheetHistory",
        "Q":"balanceSheetHistoryQuarterly",
        "B":"balanceSheetStatements"},
    "IS":{"A":"incomeStatementHistory",
        "Q":"incomeStatementHistoryQuarterly",
        "B":"incomeStatementHistory"}    }
def parse_finstmt(summary, stmt, symbol):
    df = pd.DataFrame()
    mapping = fin_stmt_mappings[stmt]
    A = summary[mapping['A']][mapping['B']]
    if A: 
        df = create_normalized_df(A, symbol)
        df['period'] = 'A'
    Q = summary[mapping['Q']][mapping['B']]
    if Q: 
        q_df = create_normalized_df(Q, symbol)
        q_df['period'] = 'Q'
        df = df.append(q_df, sort=False)
    return df

def parse_earnings_trend(summary, symbol):
    route = summary['earningsTrend']['trend']
    epsEst_df = pd.DataFrame()
    revEst_df = pd.DataFrame()
    epsTrend_df = pd.DataFrame()
    epsRev_df = pd.DataFrame()
    period_df = pd.DataFrame()

    for item in route:
        epsEst_df = epsEst_df.append(single_row_df(item.pop('earningsEstimate'), symbol), sort=False)
        revEst_df = revEst_df.append(single_row_df(item.pop('revenueEstimate'), symbol), sort=False)
        epsTrend_df = epsTrend_df.append(single_row_df(item.pop('epsTrend'), symbol), sort=False)
        epsRev_df = epsRev_df.append(single_row_df(item.pop('epsRevisions'), symbol), sort=False)
        period_df = period_df.append(clean_single_row_df(item), sort=False)

    if 'growth' in epsEst_df.columns: epsEst_df.drop(labels='growth', axis=1, inplace=True)
    if 'growth' in revEst_df.columns: revEst_df.drop(labels='growth', axis=1, inplace=True)
        
    epsEst_df = pd.concat([period_df, epsEst_df], axis=1)
    revEst_df = pd.concat([period_df, revEst_df], axis=1)
    epsTrend_df = pd.concat([period_df, epsTrend_df], axis=1)
    epsRev_df = pd.concat([period_df, epsRev_df], axis=1)
    
    return epsEst_df, revEst_df, epsTrend_df, epsRev_df

# %%
def get_mult_rows(key, summary, symbol): 
    if key in summary: return create_normalized_df(summary[key], symbol)
def get_single_row(key, summary, symbol): 
    if key in summary: return single_row_df(summary[key], symbol)

def direct_row(summary, symbol): return single_row_df(summary, symbol)
def direct_rows(summary, symbol): return create_normalized_df(summary, symbol)

# %% [markdown]
# #### Unpack the summaries

# %%
index = 55
print(fileList[index])
summary = json_load(fileList[index])[0]
# Out:
# summary/2019-02-08/CCL.json

# %%
# unpack daily summary
def unpack_summaries(dates):

    for d in dates:
        
        profile_df = pd.DataFrame()
        officers_df = pd.DataFrame()
        keyStats_df = pd.DataFrame()
        finStats_df = pd.DataFrame()
        finStmtBS_df = pd.DataFrame()
        finStmtIS_df = pd.DataFrame()
        finStmtCF_df = pd.DataFrame()
        earningsEst_df = pd.DataFrame()
        revenueEst_df = pd.DataFrame()
        epsTrend_df = pd.DataFrame()
        epsRevisions_df = pd.DataFrame()
        netSharePA_df = pd.DataFrame()
        
        print('Unpacking summary for {}'.format(d))
        fileList = list_files('summary', d)
        i = 0
        for f in fileList:
            symbol = f.split('/')[2].split('.json')[0]
            consol_summary = json_load(f)

            if consol_summary:
                summary = consol_summary[0]

                # profile
                key = 'assetProfile'
                if key in summary:
                    officers = summary[key].pop('companyOfficers')
                    if officers:
                        officers_df = officers_df.append(direct_rows(officers, symbol), sort=False)
                    profile_df = profile_df.append(get_single_row(key, summary, symbol), sort=False)

                # stats
                key = 'defaultKeyStatistics'
                if key in summary:
                    keyStats_df = keyStats_df.append(get_single_row(key, summary, symbol), sort=False)
                key = 'financialData'
                if key in summary:
                    finStats_df = finStats_df.append(get_single_row(key, summary, symbol), sort=False)

                # financials
                A, Q = fin_stmt_mappings['CF']['A'], fin_stmt_mappings['CF']['Q']
                if A in summary and Q in summary:
                    finStmtCF_df = finStmtCF_df.append(parse_finstmt(summary, 'CF', symbol), sort=False)
                A, Q = fin_stmt_mappings['BS']['A'], fin_stmt_mappings['BS']['Q']
                if A in summary and Q in summary:
                    finStmtBS_df = finStmtBS_df.append(parse_finstmt(summary, 'BS', symbol), sort=False)
                A, Q = fin_stmt_mappings['IS']['A'], fin_stmt_mappings['IS']['Q']
                if A in summary and Q in summary:
                    finStmtIS_df = finStmtIS_df.append(parse_finstmt(summary, 'IS', symbol), sort=False)

                # earningsTrend
                key = 'earningsTrend'
                if key in summary:
                    eps_est, rev_est, eps_trend, eps_rev = parse_earnings_trend(summary, symbol)
                    earningsEst_df = earningsEst_df.append(eps_est, sort=False)
                    revenueEst_df = revenueEst_df.append(rev_est, sort=False)
                    epsTrend_df = epsTrend_df.append(eps_trend, sort=False)
                    epsRevisions_df = epsRevisions_df.append(eps_rev, sort=False)

                # netSharePurchaseActivity
                key = 'netSharePurchaseActivity'
                netSharePA_df = netSharePA_df.append(get_single_row(key, summary, symbol), sort=False)

            print('{} Full unpack for {}'.format(i, symbol))
            i += 1

        # static info
        # profile
        csv_store(set_storeDate(profile_df, today_date), 'summary-categories/', csv_ext.format('assetProfile'))
        csv_store(set_storeDate(officers_df, today_date), 'summary-categories/', csv_ext.format('companyOfficers'))

        # financials -> need to find a way to append to this file
        csv_store(set_storeDate(finStmtBS_df, today_date), 'summary-categories/', csv_ext.format('financials-BS'))
        csv_store(set_storeDate(finStmtIS_df, today_date), 'summary-categories/', csv_ext.format('financials-IS'))
        csv_store(set_storeDate(finStmtCF_df, today_date), 'summary-categories/', csv_ext.format('financials-CF'))

        # should be updated daily
        fname = csv_ext.format(str(today_date))
        csv_store(set_storeDate(keyStats_df, today_date), 'summary-categories/defaultKeyStatistics/', fname)
        csv_store(set_storeDate(finStats_df, today_date), 'summary-categories/financialData/', fname)
        csv_store(set_storeDate(earningsEst_df, today_date), 'summary-categories/earningsEstimate/', fname)
        csv_store(set_storeDate(revenueEst_df, today_date), 'summary-categories/revenueEstimate/', fname)
        csv_store(set_storeDate(epsTrend_df, today_date), 'summary-categories/epsTrend/', fname)
        csv_store(set_storeDate(epsRevisions_df, today_date), 'summary-categories/epsRevisions/', fname)
        csv_store(set_storeDate(netSharePA_df, today_date), 'summary-categories/netSharePurchaseActivity/', fname)

# %%
dates[:-3:-1]
# Out:
# ['2019-02-08', '2019-02-07']

# %%
unpack_summaries(dates[:-3:-1])
# Out:
# Unpacking summary for 2019-02-08
# 0 Full unpack for 0700.HK
# 1 Full unpack for 1810.HK
# 2 Full unpack for 3690.HK
# 3 Full unpack for 9984.T
# 4 Full unpack for A
# 5 Full unpack for AAPL
# 6 Full unpack for ABBV
# 7 Full unpack for ABC
# 8 Full unpack for ABT
# 9 Full unpack for ADBE
# 10 Full unpack for ADI
# 11 Full unpack for ADSK
# 12 Full unpack for AEIS
# 13 Full unpack for AEO
# 14 Full unpack for AGN
# 15 Full unpack for AKAM
# 16 Full unpack for ALGN
# 17 Full unpack for ALLO
# 18 Full unpack for ALRM
# 19 Full unpack for ALXN
# 20 Full unpack for AMAT
# 21 Full unpack for AMD
# 22 Full unpack for AMGN
# 23 Full unpack for AMZN
# 24 Full unpack for ANET
# 25 Full unpack for ANSS
# 26 Full unpack for ANTM
# 27 Full unpack for APH
# 28 Full unpack for APTV
# 29 Full unpack for ATHN
# 30 Full unpack for ATVI
# 31 Full unpack for AVGO
# 32 Full unpack for AVX
# 33 Full unpack for AYX
# 34 Full unpack for BABA
# 35 Full unpack for BAX
# 36 Full unpack for BBY
# 37 Full unpack for BC
# 38 Full unpack for BDX
# 39 Full unpack for BGNE
# 40 Full unpack for BIDU
# 41 Full unpack for BIIB
# 42 Full unpack for BKNG
# 43 Full unpack for BL
# 44 Full unpack for BLUE
# 45 Full unpack for BMY
# 46 Full unpack for BND
# 47 Full unpack for BNDX
# 48 Full unpack for BOX
# 49 Full unpack for BRKR
# 50 Full unpack for BRKS
# 51 Full unpack for BSX
# 52 Full unpack for BWA
# 53 Full unpack for CAH
# 54 Full unpack for CBM
# 55 Full unpack for CCL
# 56 Full unpack for CCMP
# 57 Full unpack for CDNS
# 58 Full unpack for CELG
# 59 Full unpack for CERN
# 60 Full unpack for CERS
# 61 Full unpack for CGNX
# 62 Full unpack for CHKP
# 63 Full unpack for CI
# 64 Full unpack for CLLS
# 65 Full unpack for CLVS
# 66 Full unpack for CNC
# 67 Full unpack for COO
# 68 Full unpack for COUP
# 69 Full unpack for CREE
# 70 Full unpack for CRM
# 71 Full unpack for CRSP
# 72 Full unpack for CRUS
# 73 Full unpack for CSCO
# 74 Full unpack for CSOD
# 75 Full unpack for CTRP
# 76 Full unpack for CTXS
# 77 Full unpack for CVLT
# 78 Full unpack for CVS
# 79 Full unpack for CYBR
# 80 Full unpack for DATA
# 81 Full unpack for DBX
# 82 Full unpack for DDD
# 83 Full unpack for DECK
# 84 Full unpack for DGX
# 85 Full unpack for DHR
# 86 Full unpack for DIA
# 87 Full unpack for DLB
# 88 Full unpack for DLPH
# 89 Full unpack for DMLRY
# 90 Full unpack for DORM
# 91 Full unpack for DOX
# 92 Full unpack for DSW
# 93 Full unpack for DVA
# 94 Full unpack for DXCM
# 95 Full unpack for EA
# 96 Full unpack for EBAY
# 97 Full unpack for EBS
# 98 Full unpack for EDIT
# 99 Full unpack for EDU
# 100 Full unpack for EEM
# 101 Full unpack for ELLI
# 102 Full unpack for EMB
# 103 Full unpack for ETSY
# 104 Full unpack for EW
# 105 Full unpack for EXEL
# 106 Full unpack for EXPE
# 107 Full unpack for F
# 108 Full unpack for FB
# 109 Full unpack for FFIV
# 110 Full unpack for FIVE
# 111 Full unpack for FIVN
# 112 Full unpack for FL
# 113 Full unpack for FLIR
# 114 Full unpack for FTNT
# 115 Full unpack for FXI
# 116 Full unpack for GILD
# 117 Full unpack for GLW
# 118 Full unpack for GM
# 119 Full unpack for GMED
# 120 Full unpack for GNTX
# 121 Full unpack for GOOG
# 122 Full unpack for GOVT
# 123 Full unpack for GPC
# 124 Full unpack for GPS
# 125 Full unpack for GRMN
# 126 Full unpack for GRUB
# 127 Full unpack for GSKY
# 128 Full unpack for GWRE
# 129 Full unpack for HALO
# 130 Full unpack for HCA
# 131 Full unpack for HD
# 132 Full unpack for HOLX
# 133 Full unpack for HPE
# 134 Full unpack for HPQ
# 135 Full unpack for HQY
# 136 Full unpack for HRS
# 137 Full unpack for HSIC
# 138 Full unpack for HUBS
# 139 Full unpack for HUM
# 140 Full unpack for HUYA
# 141 Full unpack for HYG
# 142 Full unpack for ICE
# 143 Full unpack for ICUI
# 144 Full unpack for IDXX
# 145 Full unpack for IEF
# 146 Full unpack for IFNNY
# 147 Full unpack for IJH
# 148 Full unpack for IJR
# 149 Full unpack for ILMN
# 150 Full unpack for INCY
# 151 Full unpack for INTC
# 152 Full unpack for INTU
# 153 Full unpack for IONS
# 154 Full unpack for IOVA
# 155 Full unpack for IPGP
# 156 Full unpack for IQ
# 157 Full unpack for IQV
# 158 Full unpack for IRBT
# 159 Full unpack for ISRG
# 160 Full unpack for IWM
# 161 Full unpack for JD
# 162 Full unpack for JNJ
# 163 Full unpack for JNK
# 164 Full unpack for JNPR
# 165 Full unpack for KBE
# 166 Full unpack for KIE
# 167 Full unpack for KLAC
# 168 Full unpack for KRE
# 169 Full unpack for LGND
# 170 Full unpack for LH
# 171 Full unpack for LKQ
# 172 Full unpack for LLY
# 173 Full unpack for LOGM
# 174 Full unpack for LOW
# 175 Full unpack for LQD
# 176 Full unpack for LULU
# 177 Full unpack for MA
# 178 Full unpack for MANH
# 179 Full unpack for MASI
# 180 Full unpack for MCHP
# 181 Full unpack for MCK
# 182 Full unpack for MDSO
# 183 Full unpack for MDT
# 184 Full unpack for MELI
# 185 Full unpack for MIME
# 186 Full unpack for MKSI
# 187 Full unpack for MLNX
# 188 Full unpack for MOH
# 189 Full unpack for MOMO
# 190 Full unpack for MPWR
# 191 Full unpack for MRK
# 192 Full unpack for MRVL
# 193 Full unpack for MSFT
# 194 Full unpack for MSG
# 195 Full unpack for MSI
# 196 Full unpack for MTD
# 197 Full unpack for MTLS
# 198 Full unpack for MU
# 199 Full unpack for MUB
# 200 Full unpack for MXIM
# 201 Full unpack for MYGN
# 202 Full unpack for MYL
# 203 Full unpack for NATI
# 204 Full unpack for NCLH
# 205 Full unpack for NEOG
# 206 Full unpack for NEWR
# 207 Full unpack for NFLX
# 208 Full unpack for NICE
# 209 Full unpack for NKE
# 210 Full unpack for NKTR
# 211 Full unpack for NOW
# 212 Full unpack for NSTG
# 213 Full unpack for NTAP
# 214 Full unpack for NTGR
# 215 Full unpack for NTLA
# 216 Full unpack for NVDA
# 217 Full unpack for NVTA
# 218 Full unpack for NXPI
# 219 Full unpack for OLED
# 220 Full unpack for ONCE
# 221 Full unpack for OPRA
# 222 Full unpack for ORBK
# 223 Full unpack for ORCL
# 224 Full unpack for PACB
# 225 Full unpack for PANW
# 226 Full unpack for PAYC
# 227 Full unpack for PCTY
# 228 Full unpack for PEGA
# 229 Full unpack for PFE
# 230 Full unpack for PKI
# 231 Full unpack for PLCE
# 232 Full unpack for PLT
# 233 Full unpack for POWI
# 234 Full unpack for PRGO
# 235 Full unpack for PSTG
# 236 Full unpack for PTC
# 237 Full unpack for PYPL
# 238 Full unpack for QCOM
# 239 Full unpack for QLYS
# 240 Full unpack for QQQ
# 241 Full unpack for QRVO
# 242 Full unpack for QYLD
# 243 Full unpack for RCL
# 244 Full unpack for RDWR
# 245 Full unpack for RGEN
# 246 Full unpack for RHT
# 247 Full unpack for RMD
# 248 Full unpack for RNG
# 249 Full unpack for ROG
# 250 Full unpack for ROST
# 251 Full unpack for RUBY
# 252 Full unpack for SHOO
# 253 Full unpack for SHOP
# 254 Full unpack for SHY
# 255 Full unpack for SKX
# 256 Full unpack for SLAB
# 257 Full unpack for SMH
# 258 Full unpack for SMTC
# 259 Full unpack for SNPS
# 260 Full unpack for SOGO
# 261 Full unpack for SPLK
# 262 Full unpack for SPOT
# 263 Full unpack for SPY
# 264 Full unpack for SQ
# 265 Full unpack for SSYS
# 266 Full unpack for STMP
# 267 Full unpack for STX
# 268 Full unpack for SUPN
# 269 Full unpack for SWKS
# 270 Full unpack for SYK
# 271 Full unpack for TAL
# 272 Full unpack for TCEHY
# 273 Full unpack for TDC
# 274 Full unpack for TDOC
# 275 Full unpack for TEL
# 276 Full unpack for TER
# 277 Full unpack for TEVA
# 278 Full unpack for TIP
# 279 Full unpack for TJX
# 280 Full unpack for TLT
# 281 Full unpack for TM
# 282 Full unpack for TME
# 283 Full unpack for TMO
# 284 Full unpack for TREE
# 285 Full unpack for TRIP
# 286 Full unpack for TRMB
# 287 Full unpack for TSEM
# 288 Full unpack for TSLA
# 289 Full unpack for TSM
# 290 Full unpack for TSS
# 291 Full unpack for TTD
# 292 Full unpack for TTWO
# 293 Full unpack for TWOU
# 294 Full unpack for TWTR
# 295 Full unpack for TXN
# 296 Full unpack for TYL
# 297 Full unpack for UBNT
# 298 Full unpack for UHS
# 299 Full unpack for ULTA
# 300 Full unpack for ULTI
# 301 Full unpack for UNH
# 302 Full unpack for URBN
# 303 Full unpack for URGN
# 304 Full unpack for UTHR
# 305 Full unpack for V
# 306 Full unpack for VAR
# 307 Full unpack for VC
# 308 Full unpack for VCYT
# 309 Full unpack for VEEV
# 310 Full unpack for VIPS
# 311 Full unpack for VRSK
# 312 Full unpack for VRSN
# 313 Full unpack for VRTX
# 314 Full unpack for VSH
# 315 Full unpack for WAT
# 316 Full unpack for WB
# 317 Full unpack for WCG
# 318 Full unpack for WDAY
# 319 Full unpack for WDC
# 320 Full unpack for WIX
# 321 Full unpack for WST
# 322 Full unpack for WUBA
# 323 Full unpack for WWE
# 324 Full unpack for XAR
# 325 Full unpack for XBI
# 326 Full unpack for XES
# 327 Full unpack for XHB
# 328 Full unpack for XLB
# 329 Full unpack for XLC
# 330 Full unpack for XLE
# 331 Full unpack for XLF
# 332 Full unpack for XLI
# 333 Full unpack for XLK
# 334 Full unpack for XLNX
# 335 Full unpack for XLP
# 336 Full unpack for XLRE
# 337 Full unpack for XLU
# 338 Full unpack for XLV
# 339 Full unpack for XLY
# 340 Full unpack for XME
# 341 Full unpack for XOP
# 342 Full unpack for XRAY
# 343 Full unpack for XRT
# 344 Full unpack for YELP
# 345 Full unpack for YY
# 346 Full unpack for ZBH
# 347 Full unpack for ZEN
# 348 Full unpack for ZTS
# 349 Full unpack for ZUO
# Saved summary-categories/assetProfile.csv
# Saved summary-categories/companyOfficers.csv
# Saved summary-categories/financials-BS.csv
# Saved summary-categories/financials-IS.csv
# Saved summary-categories/financials-CF.csv
# Saved summary-categories/defaultKeyStatistics/2019-02-08.csv
# Saved summary-categories/financialData/2019-02-08.csv
# Saved summary-categories/earningsEstimate/2019-02-08.csv
# Saved summary-categories/revenueEstimate/2019-02-08.csv
# Saved summary-categories/epsTrend/2019-02-08.csv
# Saved summary-categories/epsRevisions/2019-02-08.csv
# Saved summary-categories/netSharePurchaseActivity/2019-02-08.csv
# Unpacking summary for 2019-02-07
# 0 Full unpack for 0700.HK
# 1 Full unpack for 1810.HK
# 2 Full unpack for 3690.HK
# 3 Full unpack for 9984.T
# 4 Full unpack for A
# 5 Full unpack for AAPL
# 6 Full unpack for ABBV
# 7 Full unpack for ABC
# 8 Full unpack for ABT
# 9 Full unpack for ADBE
# 10 Full unpack for ADI
# 11 Full unpack for ADSK
# 12 Full unpack for AEIS
# 13 Full unpack for AEO
# 14 Full unpack for AGN
# 15 Full unpack for AKAM
# 16 Full unpack for ALGN
# 17 Full unpack for ALLO
# 18 Full unpack for ALRM
# 19 Full unpack for ALXN
# 20 Full unpack for AMAT
# 21 Full unpack for AMD
# 22 Full unpack for AMGN
# 23 Full unpack for AMZN
# 24 Full unpack for ANET
# 25 Full unpack for ANSS
# 26 Full unpack for ANTM
# 27 Full unpack for APH
# 28 Full unpack for APTV
# 29 Full unpack for ATHN
# 30 Full unpack for ATVI
# 31 Full unpack for AVGO
# 32 Full unpack for AVX
# 33 Full unpack for AYX
# 34 Full unpack for BABA
# 35 Full unpack for BAX
# 36 Full unpack for BBY
# 37 Full unpack for BC
# 38 Full unpack for BDX
# 39 Full unpack for BGNE
# 40 Full unpack for BIDU
# 41 Full unpack for BIIB
# 42 Full unpack for BKNG
# 43 Full unpack for BL
# 44 Full unpack for BLUE
# 45 Full unpack for BMY
# 46 Full unpack for BND
# 47 Full unpack for BNDX
# 48 Full unpack for BOX
# 49 Full unpack for BRKR
# 50 Full unpack for BRKS
# 51 Full unpack for BSX
# 52 Full unpack for BWA
# 53 Full unpack for CAH
# 54 Full unpack for CBM
# 55 Full unpack for CCL
# 56 Full unpack for CCMP
# 57 Full unpack for CDNS
# 58 Full unpack for CELG
# 59 Full unpack for CERN
# 60 Full unpack for CERS
# 61 Full unpack for CGNX
# 62 Full unpack for CHKP
# 63 Full unpack for CI
# 64 Full unpack for CLLS
# 65 Full unpack for CLVS
# 66 Full unpack for CNC
# 67 Full unpack for COO
# 68 Full unpack for COUP
# 69 Full unpack for CREE
# 70 Full unpack for CRM
# 71 Full unpack for CRSP
# 72 Full unpack for CRUS
# 73 Full unpack for CSCO
# 74 Full unpack for CSOD
# 75 Full unpack for CTRP
# 76 Full unpack for CTXS
# 77 Full unpack for CVLT
# 78 Full unpack for CVS
# 79 Full unpack for CYBR
# 80 Full unpack for DATA
# 81 Full unpack for DBX
# 82 Full unpack for DDD
# 83 Full unpack for DECK
# 84 Full unpack for DGX
# 85 Full unpack for DHR
# 86 Full unpack for DIA
# 87 Full unpack for DLB
# 88 Full unpack for DLPH
# 89 Full unpack for DMLRY
# 90 Full unpack for DORM
# 91 Full unpack for DOX
# 92 Full unpack for DSW
# 93 Full unpack for DVA
# 94 Full unpack for DXCM
# 95 Full unpack for EA
# 96 Full unpack for EBAY
# 97 Full unpack for EBS
# 98 Full unpack for EDIT
# 99 Full unpack for EDU
# 100 Full unpack for EEM
# 101 Full unpack for ELLI
# 102 Full unpack for EMB
# 103 Full unpack for EMQQ
# 104 Full unpack for ETSY
# 105 Full unpack for EW
# 106 Full unpack for EXEL
# 107 Full unpack for EXPE
# 108 Full unpack for F
# 109 Full unpack for FB
# 110 Full unpack for FFIV
# 111 Full unpack for FIVE
# 112 Full unpack for FIVN
# 113 Full unpack for FL
# 114 Full unpack for FLIR
# 115 Full unpack for FTNT
# 116 Full unpack for FXI
# 117 Full unpack for GILD
# 118 Full unpack for GLW
# 119 Full unpack for GM
# 120 Full unpack for GMED
# 121 Full unpack for GNTX
# 122 Full unpack for GOOG
# 123 Full unpack for GOVT
# 124 Full unpack for GPC
# 125 Full unpack for GPS
# 126 Full unpack for GRMN
# 127 Full unpack for GRUB
# 128 Full unpack for GSKY
# 129 Full unpack for GWRE
# 130 Full unpack for HALO
# 131 Full unpack for HCA
# 132 Full unpack for HD
# 133 Full unpack for HOLX
# 134 Full unpack for HPE
# 135 Full unpack for HPQ
# 136 Full unpack for HQY
# 137 Full unpack for HRS
# 138 Full unpack for HSIC
# 139 Full unpack for HUBS
# 140 Full unpack for HUM
# 141 Full unpack for HUYA
# 142 Full unpack for HYG
# 143 Full unpack for ICE
# 144 Full unpack for ICUI
# 145 Full unpack for IDXX
# 146 Full unpack for IEF
# 147 Full unpack for IFNNY
# 148 Full unpack for IJH
# 149 Full unpack for IJR
# 150 Full unpack for ILMN
# 151 Full unpack for INCY
# 152 Full unpack for INTC
# 153 Full unpack for INTU
# 154 Full unpack for IONS
# 155 Full unpack for IOVA
# 156 Full unpack for IPGP
# 157 Full unpack for IQ
# 158 Full unpack for IQV
# 159 Full unpack for IRBT
# 160 Full unpack for ISRG
# 161 Full unpack for IWM
# 162 Full unpack for JD
# 163 Full unpack for JNJ
# 164 Full unpack for JNK
# 165 Full unpack for JNPR
# 166 Full unpack for KBE
# 167 Full unpack for KCE
# 168 Full unpack for KIE
# 169 Full unpack for KLAC
# 170 Full unpack for KRE
# 171 Full unpack for LGND
# 172 Full unpack for LH
# 173 Full unpack for LKQ
# 174 Full unpack for LLY
# 175 Full unpack for LOGM
# 176 Full unpack for LOW
# 177 Full unpack for LQD
# 178 Full unpack for LULU
# 179 Full unpack for MA
# 180 Full unpack for MANH
# 181 Full unpack for MASI
# 182 Full unpack for MCHP
# 183 Full unpack for MCK
# 184 Full unpack for MDSO
# 185 Full unpack for MDT
# 186 Full unpack for MELI
# 187 Full unpack for MIME
# 188 Full unpack for MKSI
# 189 Full unpack for MLNX
# 190 Full unpack for MOH
# 191 Full unpack for MOMO
# 192 Full unpack for MPWR
# 193 Full unpack for MRK
# 194 Full unpack for MRVL
# 195 Full unpack for MSFT
# 196 Full unpack for MSG
# 197 Full unpack for MSI
# 198 Full unpack for MTD
# 199 Full unpack for MTLS
# 200 Full unpack for MU
# 201 Full unpack for MUB
# 202 Full unpack for MXIM
# 203 Full unpack for MYGN
# 204 Full unpack for MYL
# 205 Full unpack for NATI
# 206 Full unpack for NCLH
# 207 Full unpack for NEOG
# 208 Full unpack for NEWR
# 209 Full unpack for NFLX
# 210 Full unpack for NICE
# 211 Full unpack for NKE
# 212 Full unpack for NKTR
# 213 Full unpack for NOW
# 214 Full unpack for NSTG
# 215 Full unpack for NTAP
# 216 Full unpack for NTGR
# 217 Full unpack for NTLA
# 218 Full unpack for NVDA
# 219 Full unpack for NVTA
# 220 Full unpack for NXPI
# 221 Full unpack for OLED
# 222 Full unpack for ONCE
# 223 Full unpack for OPRA
# 224 Full unpack for ORBK
# 225 Full unpack for ORCL
# 226 Full unpack for PACB
# 227 Full unpack for PANW
# 228 Full unpack for PAYC
# 229 Full unpack for PCTY
# 230 Full unpack for PEGA
# 231 Full unpack for PFE
# 232 Full unpack for PKI
# 233 Full unpack for PLCE
# 234 Full unpack for PLT
# 235 Full unpack for POWI
# 236 Full unpack for PRGO
# 237 Full unpack for PSTG
# 238 Full unpack for PTC
# 239 Full unpack for PYPL
# 240 Full unpack for QCOM
# 241 Full unpack for QLYS
# 242 Full unpack for QQQ
# 243 Full unpack for QRVO
# 244 Full unpack for QYLD
# 245 Full unpack for RCL
# 246 Full unpack for RDWR
# 247 Full unpack for RGEN
# 248 Full unpack for RHT
# 249 Full unpack for RMD
# 250 Full unpack for RNG
# 251 Full unpack for ROG
# 252 Full unpack for ROST
# 253 Full unpack for RUBY
# 254 Full unpack for SHOO
# 255 Full unpack for SHOP
# 256 Full unpack for SHY
# 257 Full unpack for SKX
# 258 Full unpack for SLAB
# 259 Full unpack for SMH
# 260 Full unpack for SMTC
# 261 Full unpack for SNPS
# 262 Full unpack for SOGO
# 263 Full unpack for SPLK
# 264 Full unpack for SPOT
# 265 Full unpack for SPY
# 266 Full unpack for SQ
# 267 Full unpack for SSYS
# 268 Full unpack for STMP
# 269 Full unpack for STX
# 270 Full unpack for SUPN
# 271 Full unpack for SWKS
# 272 Full unpack for SYK
# 273 Full unpack for TAL
# 274 Full unpack for TCEHY
# 275 Full unpack for TDC
# 276 Full unpack for TDOC
# 277 Full unpack for TEL
# 278 Full unpack for TER
# 279 Full unpack for TEVA
# 280 Full unpack for TIP
# 281 Full unpack for TJX
# 282 Full unpack for TLT
# 283 Full unpack for TM
# 284 Full unpack for TME
# 285 Full unpack for TMO
# 286 Full unpack for TREE
# 287 Full unpack for TRIP
# 288 Full unpack for TRMB
# 289 Full unpack for TSEM
# 290 Full unpack for TSLA
# 291 Full unpack for TSM
# 292 Full unpack for TSS
# 293 Full unpack for TTD
# 294 Full unpack for TTWO
# 295 Full unpack for TWOU
# 296 Full unpack for TWTR
# 297 Full unpack for TXN
# 298 Full unpack for TYL
# 299 Full unpack for UBNT
# 300 Full unpack for UHS
# 301 Full unpack for ULTA
# 302 Full unpack for ULTI
# 303 Full unpack for UNH
# 304 Full unpack for URBN
# 305 Full unpack for URGN
# 306 Full unpack for UTHR
# 307 Full unpack for V
# 308 Full unpack for VAR
# 309 Full unpack for VC
# 310 Full unpack for VCYT
# 311 Full unpack for VEEV
# 312 Full unpack for VIPS
# 313 Full unpack for VRSK
# 314 Full unpack for VRSN
# 315 Full unpack for VRTX
# 316 Full unpack for VSH
# 317 Full unpack for WAT
# 318 Full unpack for WB
# 319 Full unpack for WCG
# 320 Full unpack for WDAY
# 321 Full unpack for WDC
# 322 Full unpack for WIX
# 323 Full unpack for WST
# 324 Full unpack for WUBA
# 325 Full unpack for WWE
# 326 Full unpack for XAR
# 327 Full unpack for XBI
# 328 Full unpack for XES
# 329 Full unpack for XHB
# 330 Full unpack for XHE
# 331 Full unpack for XHS
# 332 Full unpack for XITK
# 333 Full unpack for XLB
# 334 Full unpack for XLC
# 335 Full unpack for XLE
# 336 Full unpack for XLF
# 337 Full unpack for XLI
# 338 Full unpack for XLK
# 339 Full unpack for XLNX
# 340 Full unpack for XLP
# 341 Full unpack for XLRE
# 342 Full unpack for XLU
# 343 Full unpack for XLV
# 344 Full unpack for XLY
# 345 Full unpack for XME
# 346 Full unpack for XNTK
# 347 Full unpack for XOP
# 348 Full unpack for XPH
# 349 Full unpack for XRAY
# 350 Full unpack for XRT
# 351 Full unpack for XSD
# 352 Full unpack for XSW
# 353 Full unpack for XTH
# 354 Full unpack for XTL
# 355 Full unpack for XTN
# 356 Full unpack for XWEB
# 357 Full unpack for YELP
# 358 Full unpack for YY
# 359 Full unpack for ZBH
# 360 Full unpack for ZEN
# 361 Full unpack for ZTS
# 362 Full unpack for ZUO
# Saved summary-categories/assetProfile.csv
# Saved summary-categories/companyOfficers.csv
# Saved summary-categories/financials-BS.csv
# Saved summary-categories/financials-IS.csv
# Saved summary-categories/financials-CF.csv
# Saved summary-categories/defaultKeyStatistics/2019-02-08.csv
# Saved summary-categories/financialData/2019-02-08.csv
# Saved summary-categories/earningsEstimate/2019-02-08.csv
# Saved summary-categories/revenueEstimate/2019-02-08.csv
# Saved summary-categories/epsTrend/2019-02-08.csv
# Saved summary-categories/epsRevisions/2019-02-08.csv
# Saved summary-categories/netSharePurchaseActivity/2019-02-08.csv

# %% [markdown]
# #### assetProfile

# %%
officers = summary['assetProfile'].pop('companyOfficers')

# %%
single_row_df(summary['assetProfile'], symbol)
# Out:
#            address1    city state    zip        country         phone  \
# 0  86 Morris Avenue  Summit    NJ  07901  United States  908-673-9000
#
#                   website       industry industrySymbol      sector   ...    \
# 0  http://www.celgene.com  Biotechnology           h788  Healthcare   ...
#
#   fullTimeEmployees  auditRisk  boardRisk  compensationRisk  \
# 0              7467          2          7                 2
#
#    shareHolderRightsRisk  overallRisk  governanceEpochDate  \
# 0                      3            2           1535760000
#
#    compensationAsOfEpochDate  maxAge  symbol
# 0                 1483142400   86400    CELG
#
# [1 rows x 21 columns]

# %%
create_normalized_df(officers, symbol)
# Out:
#    maxAge                         name  \
# 0       1            Mr. Mark J. Alles
# 1       1         Mr. Peter N. Kellogg
# 2       1      Dr. S. J. Rupert Vessey
# 3       1          Mr. David V. Elkins
# 4       1  Mr. Patrick E. Flanigan III
#
#                                      title  exercisedValue  unexercisedValue  \
# 0                           Chairman & CEO         1597230                 0
# 1  Exec. VP & Chief Corp. Strategy Officer               0                 0
# 2  EVP and Pres of Research & Early Devel.               0                 0
# 3                           Exec. VP & CFO               0                 0
# 4           Corp. VP of Investor Relations               0                 0
#
#   symbol
# 0   CELG
# 1   CELG
# 2   CELG
# 3   CELG
# 4   CELG

# %% [markdown]
# #### majorHoldersBreakdown

# %%
pd.DataFrame(summary['majorHoldersBreakdown']).loc['raw']
# Out:
# maxAge                                1
# insidersPercentHeld             0.00381
# institutionsPercentHeld         0.75954
# institutionsFloatPercentHeld    0.76245
# institutionsCount                  1848
# Name: raw, dtype: object

# %% [markdown]
# #### institutionOwnership

# %%
create_normalized_df(summary['institutionOwnership']['ownershipList'], symbol)
# Out:
#    maxAge  reportDate                   organization  pctHeld  position  \
# 0       1  1530316800                 Blackrock Inc.   0.0765  53793364
# 1       1  1530316800     Vanguard Group, Inc. (The)   0.0740  52056328
# 2       1  1530316800       State Street Corporation   0.0406  28588600
# 3       1  1530316800    Edgewood Management Company   0.0198  13924544
# 4       1  1530316800                   Invesco Ltd.   0.0169  11891214
# 5       1  1530316800           Orbis Allan Gray Ltd   0.0146  10255794
# 6       1  1530316800  Geode Capital Management, LLC   0.0131   9189754
# 7       1  1530316800        Franklin Resources, Inc   0.0131   9179327
# 8       1  1530316800     Northern Trust Corporation   0.0130   9138429
# 9       1  1530316800      Janus Henderson Group PLC   0.0129   9070041
#
#         value symbol
# 0  4155537369   CELG
# 1  4021351338   CELG
# 2  2208469350   CELG
# 3  1075671024   CELG
# 4   918596281   CELG
# 5   792260086   CELG
# 6   709908496   CELG
# 7   709103010   CELG
# 8   705943640   CELG
# 9   700660667   CELG

# %% [markdown]
# #### recommendationTrend

# %%
create_df(summary['recommendationTrend']['trend'], symbol)
# Out:
#   period  strongBuy  buy  hold  sell symbol
# 0     0m         11    8    11     1   CELG
# 1    -1m         14   10     2     2   CELG
# 2    -2m         12   10     3     1   CELG
# 3    -3m         12   10     4     1   CELG

# %% [markdown]
# #### earningsHistory

# %%
create_normalized_df(summary['earningsHistory']['history'], symbol)
# Out:
#    maxAge  epsActual  epsEstimate  epsDifference  surprisePercent     quarter  \
# 0       1       1.91         1.87           0.04            0.021  1506729600
# 1       1       2.00         1.97           0.03            0.015  1514678400
# 2       1       2.05         1.96           0.09            0.046  1522454400
# 3       1       2.16         2.11           0.05            0.024  1530316800
#
#   period symbol
# 0    -4q   CELG
# 1    -3q   CELG
# 2    -2q   CELG
# 3    -1q   CELG

# %% [markdown]
# #### indexTrend

# %%
summary['indexTrend']
# Out:
# {'maxAge': 1,
#  'symbol': 'SP5',
#  'peRatio': {'raw': 16.0209, 'fmt': '16.02'},
#  'pegRatio': {'raw': 1.45273, 'fmt': '1.45'},
#  'estimates': [{'period': '0q', 'growth': {'raw': 0.317, 'fmt': '0.32'}},
#   {'period': '+1q', 'growth': {'raw': 0.43400002, 'fmt': '0.43'}},
#   {'period': '0y', 'growth': {'raw': 0.24, 'fmt': '0.24'}},
#   {'period': '+1y', 'growth': {'raw': 0.269, 'fmt': '0.27'}},
#   {'period': '+5y', 'growth': {'raw': 0.109052, 'fmt': '0.11'}},
#   {'period': '-5y', 'growth': {}}]}

# %%
route = summary['indexTrend']['estimates']
df = clean_up_fmt(json_normalize(route))
df.index = get_symbol_index(df, symbol)
df
# Out:
#         growth period
# CELG  0.317000     0q
# CELG  0.434000    +1q
# CELG  0.240000     0y
# CELG  0.269000    +1y
# CELG  0.109052    +5y
# CELG       NaN    -5y

# %% [markdown]
# #### defaultKeyStatistics

# %%
single_row_df(summary['defaultKeyStatistics'], symbol)
# Out:
#    maxAge  priceHint  enterpriseValue  forwardPE  profitMargins  floatShares  \
# 0       1          2      79976955904   8.334901        0.19813    701492064
#
#    sharesOutstanding  sharesShort  sharesShortPriorMonth  \
# 0          703363008     10788473               15805908
#
#    sharesShortPreviousMonthDate   ...    trailingEps  forwardEps  pegRatio  \
# 0                    1534291200   ...          3.596       10.62      0.53
#
#    lastSplitFactor  lastSplitDate  enterpriseToRevenue  enterpriseToEbitda  \
# 0              2/1     1403740800                5.663              15.803
#
#    52WeekChange  SandP52WeekChange  symbol
# 0     -0.343833           0.146328    CELG
#
# [1 rows x 34 columns]

# %% [markdown]
# #### netSharePurchaseActivity

# %%
single_row_df(summary['netSharePurchaseActivity'], symbol)
# Out:
#    maxAge period  buyInfoCount  buyInfoShares  buyPercentInsiderShares  \
# 0       1     6m            38         243436                    0.097
#
#    sellInfoCount  sellInfoShares  sellPercentInsiderShares  netInfoCount  \
# 0              4           70500                     0.028            42
#
#    netInfoShares  netPercentInsiderShares  totalInsiderShares symbol
# 0         172936                    0.069             2679813   CELG

# %% [markdown]
# #### fundOwnership

# %%
create_normalized_df(summary['fundOwnership']['ownershipList'], symbol)
# Out:
#    maxAge  reportDate                                       organization  \
# 0       1  1514678400             Vanguard Total Stock Market Index Fund
# 1       1  1514678400                            Vanguard 500 Index Fund
# 2       1  1530316800                   iShares NASDAQ Biotechnology ETF
# 3       1  1514678400  Vanguard Institutional Index Fund-Institutiona...
# 4       1  1530316800                             SPDR S&P 500 ETF Trust
# 5       1  1530316800        Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF
# 6       1  1517356800      Advisors Inner Circle Fund-Edgewood Growth Fd
# 7       1  1514678400                         Vanguard Growth Index Fund
# 8       1  1530316800                           Fidelity  500 Index Fund
# 9       1  1530316800                           iShares Core S&P 500 ETF
#
#    pctHeld  position       value symbol
# 0   0.0270  18975558  1987689700   CELG
# 1   0.0191  13453235  1409226366   CELG
# 2   0.0117   8232189   635936600   CELG
# 3   0.0113   7973718   835246960   CELG
# 4   0.0112   7891849   609645335   CELG
# 5   0.0085   5990779   462787677   CELG
# 6   0.0080   5629547   581307035   CELG
# 7   0.0075   5301058   555285825   CELG
# 8   0.0066   4652857   359433203   CELG
# 9   0.0065   4548250   351352312   CELG

# %% [markdown]
# #### insiderHolders

# %%
create_normalized_df(summary['insiderHolders']['holders'], symbol)
# Out:
#       maxAge                 name  relation  \
# ADBE       1          BANSE AMY L  Director
# ADBE       1    BARNHOLT EDWARD W  Director
# ADBE       1     BURGESS ROBERT K  Director
# ADBE       1    CALDERONI FRANK A  Director
# ADBE       1   DALEY JAMES ERNEST  Director
# ADBE       1        DESMOND LAURA  Director
# ADBE       1    GESCHKE CHARLES M  Director
# ADBE       1           LEWNES ANN   Officer
# ADBE       1  ROSENSWEIG DANIEL L  Director
# ADBE       1       WARNOCK JOHN E  Director
#
#                              transactionDescription  latestTransDate  \
# ADBE  Conversion of Exercise of derivative security       1523404800
# ADBE  Conversion of Exercise of derivative security       1523404800
# ADBE  Conversion of Exercise of derivative security       1523404800
# ADBE  Conversion of Exercise of derivative security       1523404800
# ADBE  Conversion of Exercise of derivative security       1523404800
# ADBE  Conversion of Exercise of derivative security       1523404800
# ADBE                                           Sale       1524182400
# ADBE                                           Sale       1524009600
# ADBE  Conversion of Exercise of derivative security       1523404800
# ADBE                                           Sale       1523404800
#
#       positionIndirect  positionIndirectDate
# ADBE               NaN                   NaN
# ADBE               NaN                   NaN
# ADBE           16030.0          1.523405e+09
# ADBE               NaN                   NaN
# ADBE               NaN                   NaN
# ADBE               NaN                   NaN
# ADBE          158059.0          1.524182e+09
# ADBE               NaN                   NaN
# ADBE               NaN                   NaN
# ADBE          470344.0          1.523405e+09

# %% [markdown]
# #### earnings

# %%
financialChart = summary['earnings']['financialsChart']
finChart_df = create_normalized_df(financialChart['yearly'], symbol)
finChart_df = finChart_df.append(create_normalized_df(financialChart['quarterly'], symbol), sort=False)

earningsChart = summary['earnings']['earningsChart']
qearnChart_df = create_normalized_df(earningsChart.pop('quarterly'), symbol)
earnInfo_df = clean_up_fmt(json_normalize(earningsChart))
earnInfo_df['earningsDate'] = earningsChart['earningsDate'][0]['raw']

# %%
finChart_df
# Out:
#      date      revenue    earnings symbol
# 0    2014   7670400000  1999900000   CELG
# 1    2015   9256000000  1602000000   CELG
# 2    2016  11229000000  1999000000   CELG
# 3    2017  13003000000  2940000000   CELG
# 0  3Q2017   3287000000   988000000   CELG
# 1  4Q2017   3483000000   -81000000   CELG
# 2  1Q2018   3538000000   846000000   CELG
# 3  2Q2018   3814000000  1045000000   CELG

# %%
qearnChart_df
# Out:
#      date  actual  estimate symbol
# 0  3Q2017    1.91      1.87   CELG
# 1  4Q2017    2.00      1.97   CELG
# 2  1Q2018    2.05      1.96   CELG
# 3  2Q2018    2.16      2.11   CELG

# %%
earnInfo_df
# Out:
#    currentQuarterEstimate currentQuarterEstimateDate  \
# 0                    2.23                         3Q
#
#    currentQuarterEstimateYear  earningsDate
# 0                        2018    1540425600

# %% [markdown]
# #### calendarEvents

# %%
route = summary['calendarEvents']['earnings']
cal_df = single_row_df(summary['calendarEvents']['earnings'], symbol)
cal_df['earningsDate'] = route['earningsDate'][0]['raw']
cal_df
# Out:
#    earningsDate  earningsAverage  earningsLow  earningsHigh  revenueAverage  \
# 0    1540425600             2.23         2.16          2.35      3835350000
#
#    revenueLow  revenueHigh symbol
# 0  3725790000   3934200000   CELG

# %% [markdown]
# #### upgradeDowngradeHistory

# %%
route = summary['upgradeDowngradeHistory']['history']
create_normalized_df(route, symbol)
# Out:
#       epochGradeDate               firm            toGrade action
# ADBE      1522022400     JMP Securities     Market Perform   down
# ADBE      1521504000            DZ Bank                Buy     up
# ADBE      1513036800          JP Morgan            Neutral   down
# ADBE      1510185600                UBS                Buy   init
# ADBE      1508371200   Pivotal Research               Hold     up
# ADBE      1508112000      Deutsche Bank               Hold   down
# ADBE      1504656000  Moffett Nathanson                Buy   init
# ADBE      1503619200          Jefferies                Buy   init
# ADBE      1497225600   Pivotal Research               Sell   down
# ADBE      1493683200           Barclays         Overweight   init
# ADBE      1492041600         Guggenheim                Buy   init
# ADBE      1491955200    Stifel Nicolaus                Buy   init
# ADBE      1490313600      Credit Suisse         Outperform     up
# ADBE      1489708800         Wunderlich                Buy     up
# ADBE      1484179200   Pivotal Research               Hold   down
# ADBE      1484092800        Wells Fargo     Market Perform   init
# ADBE      1483574400        BMO Capital         Outperform   init
# ADBE      1479340800      BTIG Research            Neutral   init
# ADBE      1470787200     Stephens & Co.         Overweight   init
# ADBE      1469491200       PiperJaffray         Overweight   init
# ADBE      1466726400        Cowen & Co.         Outperform   init
# ADBE      1459382400  Canaccord Genuity                Buy   init
# ADBE      1452729600          Dougherty                Buy   init
# ADBE      1444780800  Atlantic Equities         Overweight     up
# ADBE      1441152000        Oppenheimer            Perform   init
# ADBE      1440460800              Baird         Outperform     up
# ADBE      1439251200        RBC Capital         Outperform     up
# ADBE      1433808000         Wunderlich               Hold   init
# ADBE      1431648000          JP Morgan         Overweight   init
# ADBE      1428537600     Stephens & Co.         Overweight   init
# ADBE      1424822400   Pivotal Research                Buy   init
# ADBE      1416528000          Jefferies                Buy   init
# ADBE      1416441600          Jefferies                Buy   init
# ADBE      1393200000        Susquehanna           Positive   init
# ADBE      1391472000        Sterne Agee                Buy   init
# ADBE      1387238400      Argus Capital                Buy     up
# ADBE      1377475200      Pacific Crest         Outperform     up
# ADBE      1374019200        FBR Capital     Market Perform     up
# ADBE      1372204800          Jefferies                Buy     up
# ADBE      1371600000    Bank of America                Buy     up
# ADBE      1366329600           B. Riley                Buy   init
# ADBE      1365638400      Goldman Sachs            Neutral     up
# ADBE      1365638400  Evercore Partners         Overweight   init
# ADBE      1363737600    Stifel Nicolaus               Hold   down
# ADBE      1363737600    Stifel Nicolaus               Hold   down
# ADBE      1362960000    Bank of America            Neutral   down
# ADBE      1355443200     JMP Securities  Market Outperform     up
# ADBE      1355443200     Janney Capital            Neutral   down

# %% [markdown]
# #### earningsTrend

# %%
import copy
summ2 = copy.deepcopy(summary)
epsEst_df, revEst_df, epsTrend_df, epsRev_df = parse_earnings_trend(summ2, symbol)

# %%
epsEst_df
# Out:
#    maxAge period     endDate   growth    avg   low   high  yearAgoEps  \
# 0       1     0q  2018-09-30  0.16800   2.23  2.16   2.35        1.91
# 0       1    +1q  2018-12-31  0.18000   2.36  2.20   2.51        2.00
# 0       1     0y  2018-12-31  0.17900   8.77  8.68   9.01        7.44
# 0       1    +1y  2019-12-31  0.21200  10.63  9.24  14.20        8.77
# 0       1    +5y         NaN  0.19620    NaN   NaN    NaN         NaN
# 0       1    -5y         NaN  0.25107    NaN   NaN    NaN         NaN
#
#    numberOfAnalysts symbol
# 0              23.0   CELG
# 0              23.0   CELG
# 0              24.0   CELG
# 0              25.0   CELG
# 0               NaN   CELG
# 0               NaN   CELG

# %%
revEst_df
# Out:
#    maxAge period     endDate   growth           avg           low  \
# 0       1     0q  2018-09-30  0.16800  3.835350e+09  3.725790e+09
# 0       1    +1q  2018-12-31  0.18000  3.960520e+09  3.900000e+09
# 0       1     0y  2018-12-31  0.17900  1.515120e+10  1.498950e+10
# 0       1    +1y  2019-12-31  0.21200  1.690980e+10  1.600000e+10
# 0       1    +5y         NaN  0.19620           NaN           NaN
# 0       1    -5y         NaN  0.25107           NaN           NaN
#
#            high  numberOfAnalysts  yearAgoRevenue symbol
# 0  3.934200e+09              21.0    3.287000e+09   CELG
# 0  4.083900e+09              21.0    3.483000e+09   CELG
# 0  1.537010e+10              24.0    1.300300e+10   CELG
# 0  1.772960e+10              24.0    1.515120e+10   CELG
# 0           NaN               NaN             NaN   CELG
# 0           NaN               NaN             NaN   CELG

# %%
epsTrend_df
# Out:
#    maxAge period     endDate   growth  current  7daysAgo  30daysAgo  \
# 0       1     0q  2018-09-30  0.16800     2.23      2.22       2.22
# 0       1    +1q  2018-12-31  0.18000     2.36      2.35       2.35
# 0       1     0y  2018-12-31  0.17900     8.77      8.75       8.75
# 0       1    +1y  2019-12-31  0.21200    10.63     10.60      10.60
# 0       1    +5y         NaN  0.19620      NaN       NaN        NaN
# 0       1    -5y         NaN  0.25107      NaN       NaN        NaN
#
#    60daysAgo  90daysAgo symbol
# 0       2.22       2.17   CELG
# 0       2.35       2.23   CELG
# 0       8.75       8.53   CELG
# 0      10.55      10.21   CELG
# 0        NaN        NaN   CELG
# 0        NaN        NaN   CELG

# %%
epsRev_df
# Out:
#    maxAge period     endDate   growth  upLast7days  upLast30days  \
# 0       1     0q  2018-09-30  0.16800          2.0           2.0
# 0       1    +1q  2018-12-31  0.18000          2.0           2.0
# 0       1     0y  2018-12-31  0.17900          2.0           2.0
# 0       1    +1y  2019-12-31  0.21200          2.0           2.0
# 0       1    +5y         NaN  0.19620          NaN           NaN
# 0       1    -5y         NaN  0.25107          NaN           NaN
#
#    downLast30days symbol
# 0             0.0   CELG
# 0             0.0   CELG
# 0             0.0   CELG
# 0             1.0   CELG
# 0             NaN   CELG
# 0             NaN   CELG

# %% [markdown]
# #### financialData

# %%
single_row_df(summary['financialData'], symbol)
# Out:
#    maxAge  currentPrice  targetHighPrice  targetLowPrice  targetMeanPrice  \
# 0   86400          88.6            163.0            82.0           111.65
#
#    targetMedianPrice  recommendationMean recommendationKey  \
# 0              105.5                 2.2               buy
#
#    numberOfAnalystOpinions   totalCash   ...    freeCashflow  \
# 0                       24  3416999936   ...      3493874944
#
#    operatingCashflow  earningsGrowth  revenueGrowth  grossMargins  \
# 0         3680999936           0.051          0.166       0.90575
#
#    ebitdaMargins  operatingMargins  profitMargins  financialCurrency  symbol
# 0        0.35838           0.32106        0.19813                USD    CELG
#
# [1 rows x 31 columns]

# %% [markdown]
# #### financials

# %%
summary.keys()
# Out:
# dict_keys(['assetProfile', 'recommendationTrend', 'cashflowStatementHistory', 'institutionOwnership', 'majorHoldersBreakdown', 'balanceSheetHistoryQuarterly', 'earningsHistory', 'indexTrend', 'majorDirectHolders', 'defaultKeyStatistics', 'netSharePurchaseActivity', 'incomeStatementHistory', 'fundOwnership', 'incomeStatementHistoryQuarterly', 'cashflowStatementHistoryQuarterly', 'insiderHolders', 'earnings', 'calendarEvents', 'upgradeDowngradeHistory', 'balanceSheetHistory', 'earningsTrend', 'financialData'])

# %%
route = summary['cashflowStatementHistoryQuarterly']['cashflowStatements']

# %%
parse_finstmt(summary, 'CF', symbol)
# Out:
#    maxAge     endDate   netIncome  depreciation  changeToNetincome  \
# 0       1  1514678400  2940000000     471000000         -336000000
# 1       1  1483142400  1999000000     505000000          926000000
# 2       1  1451520000  1602000000     402000000          537000000
# 3       1  1419984000  1999900000     369400000          339900000
# 0       1  1530316800  1045000000     170000000          361000000
# 1       1  1522454400   846000000     126000000         -826000000
# 2       1  1514678400   -81000000     116000000         -762000000
# 3       1  1506729600   988000000     115000000          161000000
#
#    changeToAccountReceivables  changeToLiabilities  changeToInventory  \
# 0                  -236000000            293000000          -42000000
# 1                  -222000000            626000000          -55000000
# 2                  -305000000            564000000          -51000000
# 3                  -166300000            242500000          -56500000
# 0                  -110000000            103000000          -20000000
# 1                   -47000000           -227000000            6000000
# 2                   -97000000            242000000           -5000000
# 3                   -64000000           -169000000           -5000000
#
#    changeToOperatingActivities  totalCashFromOperatingActivities   ...    \
# 0                    -73000000                        5246000000   ...
# 1                     85000000                        4165000000   ...
# 2                   -326000000                        2785000000   ...
# 3                     38300000                        2806300000   ...
# 0                   -152000000                        1229000000   ...
# 1                   -193000000                        -325000000   ...
# 2                    212000000                        1689000000   ...
# 3                   -101000000                        1088000000   ...
#
#    totalCashflowsFromInvestingActivities  netBorrowings  \
# 0                            -2891000000     1564000000
# 1                            -1002000000     1564000000
# 2                            -6259000000     7297000000
# 3                            -1438000000     2025300000
# 0                             -128000000      995000000
# 1                            -5658000000     4452000000
# 2                             1098000000     1568000000
# 3                            -2374000000       -4000000
#
#    otherCashflowsFromFinancingActivities  totalCashFromFinancingActivities  \
# 0                                    NaN                       -1584000000
# 1                            -33000000.0                       -1834000000
# 2                             -9000000.0                        4283000000
# 3                            235200000.0                        -417400000
# 0                                    NaN                       -2399000000
# 1                            -40000000.0                        1756000000
# 2                            -40000000.0                       -1292000000
# 3                            -40000000.0                         132000000
#
#    effectOfExchangeRate  changeInCash  repurchaseOfStock  issuanceOfStock  \
# 0              72000000     843000000        -3833000000        685000000
# 1             -39000000    1290000000        -2160000000        359000000
# 2             -51000000     758000000        -3257000000        252000000
# 3             -63700000     887200000        -2975100000        297200000
# 0             -18000000   -1316000000        -3396000000          2000000
# 1              33000000   -4194000000        -2700000000         44000000
# 2               7000000    1502000000        -2908000000         48000000
# 3               5000000   -1149000000         -114000000        250000000
#
#    symbol  period
# 0    CELG       A
# 1    CELG       A
# 2    CELG       A
# 3    CELG       A
# 0    CELG       Q
# 1    CELG       Q
# 2    CELG       Q
# 3    CELG       Q
#
# [8 rows x 23 columns]

# %%
parse_finstmt(summary, 'BS', symbol)
# Out:
#    maxAge     endDate        cash  shortTermInvestments  netReceivables  \
# 0       1  1514678400  7013000000            5029000000      2001000000
# 1       1  1483142400  6170000000            1800000000      1693000000
# 2       1  1451520000  4880300000            1671600000      1420900000
# 3       1  1419984000  4121600000            3425100000      1166700000
# 0       1  1530316800  1503000000            1907000000      2089000000
# 1       1  1522454400  2819000000            1921000000      1991000000
# 2       1  1514678400  7013000000            5029000000      2001000000
# 3       1  1506729600  5511000000            6248000000      1816000000
#
#    inventory  otherCurrentAssets  totalCurrentAssets  longTermInvestments  \
# 0  541000000           161000000         14892000000            1000000.0
# 1  498000000           548000000         10868000000           32000000.0
# 2  443400000           754000000          9400900000           22400000.0
# 3  393100000           588100000          9712600000            1300000.0
# 0  555000000           792000000          6853000000                  NaN
# 1  536000000           598000000          7872000000                  NaN
# 2  541000000           161000000         14892000000                  NaN
# 3  537000000           643000000         14783000000                  NaN
#
#    propertyPlantEquipment   ...      totalLiab  commonStock  retainedEarnings  \
# 0              1070000000   ...    23220000000     10000000       13061000000
# 1               930000000   ...    21486000000     10000000       10074000000
# 2               814100000   ...    21045400000      9400000        8074400000
# 3               642600000   ...    10815300000      9200000        6472400000
# 0              1292000000   ...    30014000000     10000000       15404000000
# 1              1251000000   ...    29384000000     10000000       14359000000
# 2              1070000000   ...    23220000000     10000000       13061000000
# 3              1002000000   ...    21886000000     10000000       13142000000
#
#    treasuryStock  capitalSurplus  otherStockholderEquity  \
# 0   -19956000000     13806000000               287000000
# 1   -15862000000     12378000000               419000000
# 2   -13284100000     11119300000               767700000
# 3    -9784000000      9827200000               914800000
# 0   -25819000000     13835000000              -119000000
# 1   -23274000000     14077000000              -328000000
# 2   -19956000000     13806000000               287000000
# 3   -16906000000     13604000000               337000000
#
#    totalStockholderEquity  netTangibleAssets  symbol  period
# 0              6921000000        -6381000000    CELG       A
# 1              6600000000        -8658000000    CELG       A
# 2              5919000000        -9818100000    CELG       A
# 3              6524800000          266000000    CELG       A
# 0              3430000000       -21044000000    CELG       Q
# 1              5172000000       -19445000000    CELG       Q
# 2              6921000000        -6381000000    CELG       Q
# 3              9850000000        -5153000000    CELG       Q
#
# [8 rows x 31 columns]

# %%
parse_finstmt(summary, 'IS', symbol)
# Out:
#    maxAge     endDate  totalRevenue  costOfRevenue  grossProfit  \
# 0       1  1514678400   13003000000     1294000000  11709000000
# 1       1  1483142400   11229000000     1365000000   9864000000
# 2       1  1451520000    9256000000     1949000000   7307000000
# 3       1  1419984000    7670400000      891000000   6779400000
# 0       1  1530316800    3814000000      126000000   3688000000
# 1       1  1522454400    3538000000      382000000   3156000000
# 2       1  1514678400    3483000000      242000000   3241000000
# 3       1  1506729600    3287000000      729000000   2558000000
#
#    researchDevelopment  sellingGeneralAdministrative  totalOperatingExpenses  \
# 0           3274000000                    2626000000              7523000000
# 1           3543000000                    2459000000              7725000000
# 2           2089000000                    2300000000              6617000000
# 3           1796300000                    2027900000              4973500000
# 0           1251000000                     790000000              2244000000
# 1           1956000000                     864000000              3289000000
# 2            807000000                     774000000              1902000000
# 3            736000000                     608000000              2153000000
#
#    operatingIncome  totalOtherIncomeExpenseNet        ebit  interestExpense  \
# 0       5480000000                 -1166000000  5480000000       -522000000
# 1       3504000000                 -1132000000  3504000000       -500000000
# 2       2639000000                  -616000000  2639000000       -311000000
# 3       2696900000                  -369500000  2696900000       -176100000
# 0       1570000000                  -263000000  1570000000       -192000000
# 1        249000000                   781000000   249000000       -166000000
# 2       1581000000                  -450000000  1581000000       -142000000
# 3       1134000000                  -143000000  1134000000       -127000000
#
#    incomeBeforeTax  incomeTaxExpense  netIncomeFromContinuingOps   netIncome  \
# 0       4314000000        1374000000                  2940000000  2940000000
# 1       2372000000         373000000                  1999000000  1999000000
# 2       2023000000         421000000                  1602000000  1602000000
# 3       2327400000         327500000                  1999900000  1999900000
# 0       1307000000         262000000                  1045000000  1045000000
# 1       1030000000         184000000                   846000000   846000000
# 2       1131000000        1212000000                   -81000000   -81000000
# 3        991000000           3000000                   988000000   988000000
#
#    netIncomeApplicableToCommonShares symbol period
# 0                         2940000000   CELG      A
# 1                         1999000000   CELG      A
# 2                         1602000000   CELG      A
# 3                         1999900000   CELG      A
# 0                         1045000000   CELG      Q
# 1                          846000000   CELG      Q
# 2                          -81000000   CELG      Q
# 3                          988000000   CELG      Q

# %% [markdown]
# #### Cleanups

# %%
# finStmtIS_df.columns
# cs_cols = ['totalRevenue', 'costOfRevenue', 'grossProfit',
#        'researchDevelopment', 'sellingGeneralAdministrative',
#        'totalOperatingExpenses', 'operatingIncome',
#        'totalOtherIncomeExpenseNet', 'ebit', 'interestExpense',
#        'incomeBeforeTax', 'incomeTaxExpense', 'minorityInterest',
#        'netIncomeFromContinuingOps', 'discontinuedOperations', 'netIncome',
#        'netIncomeApplicableToCommonShares']
# cs_hist_cols = ['costOfRevenue', 'grossProfit', 'researchDevelopment', 
#                 'sellingGeneralAdministrative', 'operatingIncome',
#                 'ebit', 'interestExpense','incomeTaxExpense',
#                 'netIncomeFromContinuingOps','netIncome']
# finStmtCF_df.info(), finStmtBS_df.info(), finStmtIS_df.info()
# is_df = finStmtIS_df[(finStmtIS_df.period == 'A') & (finStmtIS_df.endDate == 1514678400)][cs_cols].copy()
# cs_df = (is_df.T / is_df.totalRevenue.values).T
# cs_df[cs_df.columns[1:6]].plot.hist(range=(0, 1), alpha=0.5)
# cs_df.sort_values(by='netIncomeApplicableToCommonShares', ascending=False)

# %%
path = get_path('summary', d)
'temp/' + json_ext.format(symbol)
# Out:
# 'temp/A.json'

# %%
dates[0], get_path('summary', dates[0])
# Out:
# ('2018-09-07', 'summary/2018-09-07/')

# %%
fileList = list_files('summary', dates[0])

# %%
fileList = list_files('summary', dates[0])
for f in fileList:
    symbol = f.split('/')[2].split('.')[0]
    consol_summary = json_load(f)
    if type(consol_summary) is dict:
        print('processing:', f)
        l = consol_summary['quoteSummary']['result']
        data = json.dumps(l)
        path = get_path('summary', dates[0])
        store_s3(data, path + json_ext.format(symbol))
        print('saving:', path + json_ext.format(symbol))
# Out:
# processing: summary/2018-09-07/ATVI.json
# saving: summary/2018-09-07/ATVI.json
# processing: summary/2018-09-07/AVX.json
# saving: summary/2018-09-07/AVX.json
# processing: summary/2018-09-07/AYX.json
# saving: summary/2018-09-07/AYX.json
# processing: summary/2018-09-07/BBY.json
# saving: summary/2018-09-07/BBY.json
# processing: summary/2018-09-07/BC.json
# saving: summary/2018-09-07/BC.json
# processing: summary/2018-09-07/BKNG.json
# saving: summary/2018-09-07/BKNG.json
# processing: summary/2018-09-07/BL.json
# saving: summary/2018-09-07/BL.json
# processing: summary/2018-09-07/BMY.json
# saving: summary/2018-09-07/BMY.json
# processing: summary/2018-09-07/BOX.json
# saving: summary/2018-09-07/BOX.json
# processing: summary/2018-09-07/BRKR.json
# saving: summary/2018-09-07/BRKR.json
# processing: summary/2018-09-07/BRKS.json
# saving: summary/2018-09-07/BRKS.json
# processing: summary/2018-09-07/CA.json
# saving: summary/2018-09-07/CA.json
# processing: summary/2018-09-07/CAKE.json
# saving: summary/2018-09-07/CAKE.json
# processing: summary/2018-09-07/CBM.json
# saving: summary/2018-09-07/CBM.json
# processing: summary/2018-09-07/CCMP.json
# saving: summary/2018-09-07/CCMP.json
# processing: summary/2018-09-07/CDNS.json
# saving: summary/2018-09-07/CDNS.json
# processing: summary/2018-09-07/CERN.json
# saving: summary/2018-09-07/CERN.json
# processing: summary/2018-09-07/CGNX.json
# saving: summary/2018-09-07/CGNX.json
# processing: summary/2018-09-07/CHGG.json
# saving: summary/2018-09-07/CHGG.json
# processing: summary/2018-09-07/CI.json
# saving: summary/2018-09-07/CI.json
# processing: summary/2018-09-07/CMG.json
# saving: summary/2018-09-07/CMG.json
# processing: summary/2018-09-07/CNC.json
# saving: summary/2018-09-07/CNC.json
# processing: summary/2018-09-07/COLM.json
# saving: summary/2018-09-07/COLM.json
# processing: summary/2018-09-07/COUP.json
# saving: summary/2018-09-07/COUP.json
# processing: summary/2018-09-07/CREE.json
# saving: summary/2018-09-07/CREE.json
# processing: summary/2018-09-07/CRM.json
# saving: summary/2018-09-07/CRM.json
# processing: summary/2018-09-07/CRUS.json
# saving: summary/2018-09-07/CRUS.json
# processing: summary/2018-09-07/CSCO.json
# saving: summary/2018-09-07/CSCO.json
# processing: summary/2018-09-07/CSOD.json
# saving: summary/2018-09-07/CSOD.json
# processing: summary/2018-09-07/CSU.json
# saving: summary/2018-09-07/CSU.json
# processing: summary/2018-09-07/CTSH.json
# saving: summary/2018-09-07/CTSH.json
# processing: summary/2018-09-07/CVCO.json
# saving: summary/2018-09-07/CVCO.json
# processing: summary/2018-09-07/CVLT.json
# saving: summary/2018-09-07/CVLT.json
# processing: summary/2018-09-07/DATA.json
# saving: summary/2018-09-07/DATA.json
# processing: summary/2018-09-07/DBX.json
# saving: summary/2018-09-07/DBX.json
# processing: summary/2018-09-07/DECK.json
# saving: summary/2018-09-07/DECK.json
# processing: summary/2018-09-07/DLB.json
# saving: summary/2018-09-07/DLB.json
# processing: summary/2018-09-07/DORM.json
# saving: summary/2018-09-07/DORM.json
# processing: summary/2018-09-07/DOX.json
# saving: summary/2018-09-07/DOX.json
# processing: summary/2018-09-07/DSW.json
# saving: summary/2018-09-07/DSW.json
# processing: summary/2018-09-07/DXCM.json
# saving: summary/2018-09-07/DXCM.json
# processing: summary/2018-09-07/EA.json
# saving: summary/2018-09-07/EA.json
# processing: summary/2018-09-07/EBS.json
# saving: summary/2018-09-07/EBS.json
# processing: summary/2018-09-07/EEFT.json
# saving: summary/2018-09-07/EEFT.json
# processing: summary/2018-09-07/ELLI.json
# saving: summary/2018-09-07/ELLI.json
# processing: summary/2018-09-07/EPAM.json
# saving: summary/2018-09-07/EPAM.json
# processing: summary/2018-09-07/ETSY.json
# saving: summary/2018-09-07/ETSY.json
# processing: summary/2018-09-07/EW.json
# saving: summary/2018-09-07/EW.json
# processing: summary/2018-09-07/EXEL.json
# saving: summary/2018-09-07/EXEL.json
# processing: summary/2018-09-07/EXLS.json
# saving: summary/2018-09-07/EXLS.json
# processing: summary/2018-09-07/EXPE.json
# saving: summary/2018-09-07/EXPE.json
# processing: summary/2018-09-07/F.json
# saving: summary/2018-09-07/F.json
# processing: summary/2018-09-07/FB.json
# saving: summary/2018-09-07/FB.json
# processing: summary/2018-09-07/FFIV.json
# saving: summary/2018-09-07/FFIV.json
# processing: summary/2018-09-07/FIVE.json
# saving: summary/2018-09-07/FIVE.json
# processing: summary/2018-09-07/FIVN.json
# saving: summary/2018-09-07/FIVN.json
# processing: summary/2018-09-07/FL.json
# saving: summary/2018-09-07/FL.json
# processing: summary/2018-09-07/FLIR.json
# saving: summary/2018-09-07/FLIR.json
# processing: summary/2018-09-07/FSLR.json
# saving: summary/2018-09-07/FSLR.json
# processing: summary/2018-09-07/FTNT.json
# saving: summary/2018-09-07/FTNT.json
# processing: summary/2018-09-07/GHC.json
# saving: summary/2018-09-07/GHC.json
# processing: summary/2018-09-07/GILD.json
# saving: summary/2018-09-07/GILD.json
# processing: summary/2018-09-07/GM.json
# saving: summary/2018-09-07/GM.json
# processing: summary/2018-09-07/GMED.json
# saving: summary/2018-09-07/GMED.json
# processing: summary/2018-09-07/GNTX.json
# saving: summary/2018-09-07/GNTX.json
# processing: summary/2018-09-07/GOOG.json
# saving: summary/2018-09-07/GOOG.json
# processing: summary/2018-09-07/GPS.json
# saving: summary/2018-09-07/GPS.json
# processing: summary/2018-09-07/GRPN.json
# saving: summary/2018-09-07/GRPN.json
# processing: summary/2018-09-07/GRUB.json
# saving: summary/2018-09-07/GRUB.json
# processing: summary/2018-09-07/GSKY.json
# saving: summary/2018-09-07/GSKY.json
# processing: summary/2018-09-07/GWRE.json
# saving: summary/2018-09-07/GWRE.json
# processing: summary/2018-09-07/HALO.json
# saving: summary/2018-09-07/HALO.json
# processing: summary/2018-09-07/HQY.json
# saving: summary/2018-09-07/HQY.json
# processing: summary/2018-09-07/HRB.json
# saving: summary/2018-09-07/HRB.json
# processing: summary/2018-09-07/HUBS.json
# saving: summary/2018-09-07/HUBS.json
# processing: summary/2018-09-07/HUM.json
# saving: summary/2018-09-07/HUM.json
# processing: summary/2018-09-07/ICUI.json
# saving: summary/2018-09-07/ICUI.json
# processing: summary/2018-09-07/IDCC.json
# saving: summary/2018-09-07/IDCC.json
# processing: summary/2018-09-07/ILMN.json
# saving: summary/2018-09-07/ILMN.json
# processing: summary/2018-09-07/INTU.json
# saving: summary/2018-09-07/INTU.json
# processing: summary/2018-09-07/IONS.json
# saving: summary/2018-09-07/IONS.json
# processing: summary/2018-09-07/IPGP.json
# saving: summary/2018-09-07/IPGP.json
# processing: summary/2018-09-07/IRBT.json
# saving: summary/2018-09-07/IRBT.json
# processing: summary/2018-09-07/ISRG.json
# saving: summary/2018-09-07/ISRG.json
# processing: summary/2018-09-07/JNPR.json
# saving: summary/2018-09-07/JNPR.json
# processing: summary/2018-09-07/KLAC.json
# saving: summary/2018-09-07/KLAC.json
# processing: summary/2018-09-07/LGND.json
# saving: summary/2018-09-07/LGND.json
# processing: summary/2018-09-07/LOGM.json
# saving: summary/2018-09-07/LOGM.json
# processing: summary/2018-09-07/LOPE.json
# saving: summary/2018-09-07/LOPE.json
# processing: summary/2018-09-07/LRCX.json
# saving: summary/2018-09-07/LRCX.json
# processing: summary/2018-09-07/LULU.json
# saving: summary/2018-09-07/LULU.json
# processing: summary/2018-09-07/MA.json
# saving: summary/2018-09-07/MA.json
# processing: summary/2018-09-07/MANH.json
# saving: summary/2018-09-07/MANH.json
# processing: summary/2018-09-07/MASI.json
# saving: summary/2018-09-07/MASI.json
# processing: summary/2018-09-07/MDSO.json
# saving: summary/2018-09-07/MDSO.json
# processing: summary/2018-09-07/MIME.json
# saving: summary/2018-09-07/MIME.json
# processing: summary/2018-09-07/MKSI.json
# saving: summary/2018-09-07/MKSI.json
# processing: summary/2018-09-07/MOH.json
# saving: summary/2018-09-07/MOH.json
# processing: summary/2018-09-07/MPWR.json
# saving: summary/2018-09-07/MPWR.json
# processing: summary/2018-09-07/MRVL.json
# saving: summary/2018-09-07/MRVL.json
# processing: summary/2018-09-07/MSFT.json
# saving: summary/2018-09-07/MSFT.json
# processing: summary/2018-09-07/MSG.json
# saving: summary/2018-09-07/MSG.json
# processing: summary/2018-09-07/MU.json
# saving: summary/2018-09-07/MU.json
# processing: summary/2018-09-07/MXIM.json
# saving: summary/2018-09-07/MXIM.json
# processing: summary/2018-09-07/MYGN.json
# saving: summary/2018-09-07/MYGN.json
# processing: summary/2018-09-07/NATI.json
# saving: summary/2018-09-07/NATI.json
# processing: summary/2018-09-07/NEOG.json
# saving: summary/2018-09-07/NEOG.json
# processing: summary/2018-09-07/NEWR.json
# saving: summary/2018-09-07/NEWR.json
# processing: summary/2018-09-07/NKE.json
# saving: summary/2018-09-07/NKE.json
# processing: summary/2018-09-07/NOW.json
# saving: summary/2018-09-07/NOW.json
# processing: summary/2018-09-07/NTAP.json
# saving: summary/2018-09-07/NTAP.json
# processing: summary/2018-09-07/NTGR.json
# saving: summary/2018-09-07/NTGR.json
# processing: summary/2018-09-07/NVDA.json
# saving: summary/2018-09-07/NVDA.json
# processing: summary/2018-09-07/NWS.json
# saving: summary/2018-09-07/NWS.json
# processing: summary/2018-09-07/NWSA.json
# saving: summary/2018-09-07/NWSA.json
# processing: summary/2018-09-07/OLED.json
# saving: summary/2018-09-07/OLED.json
# processing: summary/2018-09-07/OLLI.json
# saving: summary/2018-09-07/OLLI.json
# processing: summary/2018-09-07/ORCL.json
# saving: summary/2018-09-07/ORCL.json
# processing: summary/2018-09-07/PANW.json
# saving: summary/2018-09-07/PANW.json
# processing: summary/2018-09-07/PAYC.json
# saving: summary/2018-09-07/PAYC.json
# processing: summary/2018-09-07/PAYX.json
# saving: summary/2018-09-07/PAYX.json
# processing: summary/2018-09-07/PCTY.json
# saving: summary/2018-09-07/PCTY.json
# processing: summary/2018-09-07/PEGA.json
# saving: summary/2018-09-07/PEGA.json
# processing: summary/2018-09-07/PLCE.json
# saving: summary/2018-09-07/PLCE.json
# processing: summary/2018-09-07/PLT.json
# saving: summary/2018-09-07/PLT.json
# processing: summary/2018-09-07/POWI.json
# saving: summary/2018-09-07/POWI.json
# processing: summary/2018-09-07/PSTG.json
# saving: summary/2018-09-07/PSTG.json
# processing: summary/2018-09-07/QCOM.json
# saving: summary/2018-09-07/QCOM.json
# processing: summary/2018-09-07/QLYS.json
# saving: summary/2018-09-07/QLYS.json
# processing: summary/2018-09-07/REGN.json
# saving: summary/2018-09-07/REGN.json
# processing: summary/2018-09-07/RGEN.json
# saving: summary/2018-09-07/RGEN.json
# processing: summary/2018-09-07/RHT.json
# saving: summary/2018-09-07/RHT.json
# processing: summary/2018-09-07/RL.json
# saving: summary/2018-09-07/RL.json
# processing: summary/2018-09-07/RNG.json
# saving: summary/2018-09-07/RNG.json
# processing: summary/2018-09-07/ROG.json
# saving: summary/2018-09-07/ROG.json
# processing: summary/2018-09-07/ROST.json
# saving: summary/2018-09-07/ROST.json
# processing: summary/2018-09-07/SHAK.json
# saving: summary/2018-09-07/SHAK.json
# processing: summary/2018-09-07/SHOO.json
# saving: summary/2018-09-07/SHOO.json
# processing: summary/2018-09-07/SKX.json
# saving: summary/2018-09-07/SKX.json
# processing: summary/2018-09-07/SLAB.json
# saving: summary/2018-09-07/SLAB.json
# processing: summary/2018-09-07/SMTC.json
# saving: summary/2018-09-07/SMTC.json
# processing: summary/2018-09-07/SNPS.json
# saving: summary/2018-09-07/SNPS.json
# processing: summary/2018-09-07/SPLK.json
# saving: summary/2018-09-07/SPLK.json
# processing: summary/2018-09-07/SQ.json
# saving: summary/2018-09-07/SQ.json
# processing: summary/2018-09-07/STMP.json
# saving: summary/2018-09-07/STMP.json
# processing: summary/2018-09-07/SUPN.json
# saving: summary/2018-09-07/SUPN.json
# processing: summary/2018-09-07/SWKS.json
# saving: summary/2018-09-07/SWKS.json
# processing: summary/2018-09-07/TDC.json
# saving: summary/2018-09-07/TDC.json
# processing: summary/2018-09-07/TER.json
# saving: summary/2018-09-07/TER.json
# processing: summary/2018-09-07/THO.json
# saving: summary/2018-09-07/THO.json
# processing: summary/2018-09-07/TIF.json
# saving: summary/2018-09-07/TIF.json
# processing: summary/2018-09-07/TJX.json
# saving: summary/2018-09-07/TJX.json
# processing: summary/2018-09-07/TRIP.json
# saving: summary/2018-09-07/TRIP.json
# processing: summary/2018-09-07/TTD.json
# saving: summary/2018-09-07/TTD.json
# processing: summary/2018-09-07/TTWO.json
# saving: summary/2018-09-07/TTWO.json
# processing: summary/2018-09-07/TWTR.json
# saving: summary/2018-09-07/TWTR.json
# processing: summary/2018-09-07/TXN.json
# saving: summary/2018-09-07/TXN.json
# processing: summary/2018-09-07/TXRH.json
# saving: summary/2018-09-07/TXRH.json
# processing: summary/2018-09-07/TYL.json
# saving: summary/2018-09-07/TYL.json
# processing: summary/2018-09-07/UBNT.json
# saving: summary/2018-09-07/UBNT.json
# processing: summary/2018-09-07/ULTA.json
# saving: summary/2018-09-07/ULTA.json
# processing: summary/2018-09-07/ULTI.json
# saving: summary/2018-09-07/ULTI.json
# processing: summary/2018-09-07/URBN.json
# saving: summary/2018-09-07/URBN.json
# processing: summary/2018-09-07/UTHR.json
# saving: summary/2018-09-07/UTHR.json
# processing: summary/2018-09-07/VAC.json
# saving: summary/2018-09-07/VAC.json
# processing: summary/2018-09-07/VAR.json
# saving: summary/2018-09-07/VAR.json
# processing: summary/2018-09-07/VC.json
# saving: summary/2018-09-07/VC.json
# processing: summary/2018-09-07/VEEV.json
# saving: summary/2018-09-07/VEEV.json
# processing: summary/2018-09-07/VRTX.json
# saving: summary/2018-09-07/VRTX.json
# processing: summary/2018-09-07/VSH.json
# saving: summary/2018-09-07/VSH.json
# processing: summary/2018-09-07/WAT.json
# saving: summary/2018-09-07/WAT.json
# processing: summary/2018-09-07/WCG.json
# saving: summary/2018-09-07/WCG.json
# processing: summary/2018-09-07/WDAY.json
# saving: summary/2018-09-07/WDAY.json
# processing: summary/2018-09-07/WST.json
# saving: summary/2018-09-07/WST.json
# processing: summary/2018-09-07/WWE.json
# saving: summary/2018-09-07/WWE.json
# processing: summary/2018-09-07/XLNX.json
# saving: summary/2018-09-07/XLNX.json
# processing: summary/2018-09-07/YELP.json
# saving: summary/2018-09-07/YELP.json
# processing: summary/2018-09-07/Z.json
# saving: summary/2018-09-07/Z.json
# processing: summary/2018-09-07/ZEN.json
# saving: summary/2018-09-07/ZEN.json
# processing: summary/2018-09-07/ZG.json
# saving: summary/2018-09-07/ZG.json
# processing: summary/2018-09-07/ZNGA.json
# saving: summary/2018-09-07/ZNGA.json
